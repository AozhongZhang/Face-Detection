# %%
'''
step-2
'''
import random


def data_split(full_list, ratio, shuffle=False):
    """
    数据集拆分: 将列表full_list按比例ratio（随机）划分为2个子列表sublist_1与sublist_2
    :param full_list: 数据列表
    :param ratio:     子列表1
    :param shuffle:   子列表2
    :return:
    """
    n_total = len(full_list)
    offset = int(n_total * ratio)
    if n_total == 0 or offset < 1:
        return [], full_list
    if shuffle:
        random.shuffle(full_list)
    sublist_1 = full_list[:offset]
    sublist_2 = full_list[offset:]
    return sublist_1, sublist_2

if __name__ == "__main__":
    data = list(range(240))
    trainset, testset = data_split(data, ratio=0.8, shuffle=True)
    print(trainset)
    print(testset)
# Out:
# [119, 60, 178, 155, 179, 49, 137, 2, 4, 70, 233, 226, 135, 41, 7, 10, 54, 201, 217, 231, 145, 169, 230, 102, 1, 197, 131, 227, 129, 34, 112, 91, 126, 46, 167, 229, 74, 43, 56, 120, 214, 80, 64, 100, 142, 175, 195, 58, 149, 107, 30, 128, 38, 73, 208, 72, 212, 93, 157, 224, 238, 153, 203, 141, 146, 23, 147, 105, 87, 77, 82, 202, 13, 37, 235, 106, 79, 26, 18, 188, 207, 143, 110, 205, 104, 168, 166, 170, 16, 71, 139, 162, 152, 161, 69, 127, 198, 116, 11, 101, 78, 33, 66, 165, 94, 44, 57, 211, 138, 199, 232, 121, 22, 39, 122, 182, 173, 75, 174, 31, 221, 171, 176, 0, 61, 118, 133, 68, 190, 17, 55, 125, 86, 189, 204, 124, 151, 156, 12, 185, 150, 6, 184, 96, 180, 51, 84, 19, 3, 9, 194, 206, 160, 159, 163, 132, 50, 134, 83, 59, 47, 219, 209, 237, 192, 114, 88, 53, 48, 183, 130, 148, 89, 40, 191, 52, 99, 210, 136, 62, 92, 97, 25, 20, 90, 67, 228, 21, 164, 108, 220, 187]
# ...

# %%
trainset = [119, 60, 178, 155, 179, 49, 137, 2, 4, 70, 233, 226, 135, 41, 7, 10, 54, 201, 217, 231, 145, 169, 230, 102, 1, 197, 131, 227, 129, 34, 112, 91, 126, 46, 167, 229, 74, 43, 56, 120, 214, 80, 64, 100, 142, 175, 195, 58, 149, 107, 30, 128, 38, 73, 208, 72, 212, 93, 157, 224, 238, 153, 203, 141, 146, 23, 147, 105, 87, 77, 82, 202, 13, 37, 235, 106, 79, 26, 18, 188, 207, 143, 110, 205, 104, 168, 166, 170, 16, 71, 139, 162, 152, 161, 69, 127, 198, 116, 11, 101, 78, 33, 66, 165, 94, 44, 57, 211, 138, 199, 232, 121, 22, 39, 122, 182, 173, 75, 174, 31, 221, 171, 176, 0, 61, 118, 133, 68, 190, 17, 55, 125, 86, 189, 204, 124, 151, 156, 12, 185, 150, 6, 184, 96, 180, 51, 84, 19, 3, 9, 194, 206, 160, 159, 163, 132, 50, 134, 83, 59, 47, 219, 209, 237, 192, 114, 88, 53, 48, 183, 130, 148, 89, 40, 191, 52, 99, 210, 136, 62, 92, 97, 25, 20, 90, 67, 228, 21, 164, 108, 220, 187]
testset = [98, 95, 222, 76, 29, 181, 158, 81, 5, 123, 8, 236, 200, 65, 216, 115, 144, 111, 218, 42, 196, 109, 154, 225, 113, 36, 177, 28, 234, 215, 85, 27, 140, 32, 186, 15, 213, 24, 14, 223, 117, 45, 35, 193, 63, 172, 239, 103]

# %%
list_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256.txt"
# list_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256.txt"

out_train_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256_train_2.txt"
out_test_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256_test_2.txt"

# out_train_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256_train_2.txt"
# out_test_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256_test_2.txt"

out_train = open(out_train_file, 'w')
out_test = open(out_test_file, 'w')

with open(list_file,'r') as f:
    lines = f.readlines()
for line in lines:
    filename = line.strip()
#     print(filename)
    face_id = filename.split('/')[10]
#     print(face_id)
    if(int(face_id) in trainset):
        out_train.write(line)
    else:
        out_test.write(line)
out_train.close()
out_test.close()

# %%
d = {'a': 1, 'b': 5, 'c': 2,'d':4}

max_key = max(d,key=d.get)
print(max_key)
# Out:
# b

# %%
a = list(d.keys())
b = list(d.items())
b
# Out:
# [('a', 1), ('b', 5), ('c', 2), ('d', 4)]

# %%
'''
step-2
'''
import random


def data_split(full_list, ratio, shuffle=False):
    """
    数据集拆分: 将列表full_list按比例ratio（随机）划分为2个子列表sublist_1与sublist_2
    :param full_list: 数据列表
    :param ratio:     子列表1
    :param shuffle:   子列表2
    :return:
    """
    n_total = len(full_list)
    offset = int(n_total * ratio)
    if n_total == 0 or offset < 1:
        return [], full_list
    if shuffle:
        random.shuffle(full_list)
    sublist_1 = full_list[:offset]
    sublist_2 = full_list[offset:]
    return sublist_1, sublist_2

if __name__ == "__main__":
    data = list(range(240))
    trainset, testset = data_split(data, ratio=0.8, shuffle=True)
    print(trainset)
    print(testset)
# Out:
# [119, 60, 178, 155, 179, 49, 137, 2, 4, 70, 233, 226, 135, 41, 7, 10, 54, 201, 217, 231, 145, 169, 230, 102, 1, 197, 131, 227, 129, 34, 112, 91, 126, 46, 167, 229, 74, 43, 56, 120, 214, 80, 64, 100, 142, 175, 195, 58, 149, 107, 30, 128, 38, 73, 208, 72, 212, 93, 157, 224, 238, 153, 203, 141, 146, 23, 147, 105, 87, 77, 82, 202, 13, 37, 235, 106, 79, 26, 18, 188, 207, 143, 110, 205, 104, 168, 166, 170, 16, 71, 139, 162, 152, 161, 69, 127, 198, 116, 11, 101, 78, 33, 66, 165, 94, 44, 57, 211, 138, 199, 232, 121, 22, 39, 122, 182, 173, 75, 174, 31, 221, 171, 176, 0, 61, 118, 133, 68, 190, 17, 55, 125, 86, 189, 204, 124, 151, 156, 12, 185, 150, 6, 184, 96, 180, 51, 84, 19, 3, 9, 194, 206, 160, 159, 163, 132, 50, 134, 83, 59, 47, 219, 209, 237, 192, 114, 88, 53, 48, 183, 130, 148, 89, 40, 191, 52, 99, 210, 136, 62, 92, 97, 25, 20, 90, 67, 228, 21, 164, 108, 220, 187]
# ...

# %%
trainset = [119, 60, 178, 155, 179, 49, 137, 2, 4, 70, 233, 226, 135, 41, 7, 10, 54, 201, 217, 231, 145, 169, 230, 102, 1, 197, 131, 227, 129, 34, 112, 91, 126, 46, 167, 229, 74, 43, 56, 120, 214, 80, 64, 100, 142, 175, 195, 58, 149, 107, 30, 128, 38, 73, 208, 72, 212, 93, 157, 224, 238, 153, 203, 141, 146, 23, 147, 105, 87, 77, 82, 202, 13, 37, 235, 106, 79, 26, 18, 188, 207, 143, 110, 205, 104, 168, 166, 170, 16, 71, 139, 162, 152, 161, 69, 127, 198, 116, 11, 101, 78, 33, 66, 165, 94, 44, 57, 211, 138, 199, 232, 121, 22, 39, 122, 182, 173, 75, 174, 31, 221, 171, 176, 0, 61, 118, 133, 68, 190, 17, 55, 125, 86, 189, 204, 124, 151, 156, 12, 185, 150, 6, 184, 96, 180, 51, 84, 19, 3, 9, 194, 206, 160, 159, 163, 132, 50, 134, 83, 59, 47, 219, 209, 237, 192, 114, 88, 53, 48, 183, 130, 148, 89, 40, 191, 52, 99, 210, 136, 62, 92, 97, 25, 20, 90, 67, 228, 21, 164, 108, 220, 187]
testset = [98, 95, 222, 76, 29, 181, 158, 81, 5, 123, 8, 236, 200, 65, 216, 115, 144, 111, 218, 42, 196, 109, 154, 225, 113, 36, 177, 28, 234, 215, 85, 27, 140, 32, 186, 15, 213, 24, 14, 223, 117, 45, 35, 193, 63, 172, 239, 103]

# %%
list_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256.txt"
# list_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256.txt"

out_train_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256_train_2.txt"
out_test_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_IR_p_faces_frontal_256_test_2.txt"

# out_train_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256_train_2.txt"
# out_test_file = "H:/BaiduNetdiskDownload/1000-dataset_images/all_VIS_faces_frontal_256_test_2.txt"

out_train = open(out_train_file, 'w')
out_test = open(out_test_file, 'w')

with open(list_file,'r') as f:
    lines = f.readlines()
for line in lines:
    filename = line.strip()
#     print(filename)
    face_id = filename.split('/')[10]
#     print(face_id)
    if(int(face_id) in trainset):
        out_train.write(line)
    else:
        out_test.write(line)
out_train.close()
out_test.close()

# %%
data = [548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 548, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 549, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 550, 551, 551, 551, 551, 551, 551, 551, 551, 551, 551, 551, 551, 551,